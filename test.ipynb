# %%
from zotero_notion_sync import config
import requests
from typing import Optional
import json

# %%
# Zotero
zotero_headers = {"Zotero-API-Key": config.ZOTERO_API_KEY}
zotero_base_url = f"https://api.zotero.org/users/{config.ZOTERO_USER_ID}"
zotero_params = {"format": "json"}

# Notion
notion_headers = {
    "Authorization": f"Bearer {config.NOTION_API_KEY}",
    "Content-Type": "application/json",
    "Notion-Version": "2022-06-28",
}
notion_db_id = config.NOTION_DATABASE_ID
notion_base_url = "https://api.notion.com/v1"
# Notion fields name
nt_title = "Title"
nt_collections = "Collections"
nt_authors = "Authors"
nt_source_url = "Source URL"
nt_tags = "Tags"
nt_item_type = "Item Type"
nt_publisher = "Publisher"
nt_extra = "Extra"
nt_doi = "DOI"
nt_abstract = "Abstract"
nt_status = "Status"
nt_category = "Category"
nt_date_accessed = "Date Accessed"
nt_publication_date = "Publication Date"
nt_modified_date = "Modified Date"

# %%
# Fetch Zotero references

zotero_items_url = zotero_base_url + "/items"

response = requests.get(
    zotero_items_url, headers=zotero_headers, params=zotero_params, timeout=30
)
response_data = response.json()

# %%
response.headers

# `rel="next"` exists in the headers, this means there are more than one response url
# Out:
# {'Date': 'Mon, 24 Feb 2025 10:50:29 GMT', 'Content-Type': 'application/json', 'Content-Length': '12585', 'Connection': 'keep-alive', 'Server': 'Apache/2.4.62 ()', 'Strict-Transport-Security': 'max-age=31536000; includeSubDomains; preload', 'Zotero-API-Version': '3', 'Zotero-Schema-Version': '28', 'Total-Results': '110', 'Link': '<https://api.zotero.org/users/15574376/items?start=25>; rel="next", <https://api.zotero.org/users/15574376/items?start=100>; rel="last", <https://www.zotero.org/users/15574376/items>; rel="alternate"', 'Last-Modified-Version': '528', 'Vary': 'Accept-Encoding', 'Content-Encoding': 'gzip'}

# %%
next_url = zotero_items_url
zotero_references = []


while next_url:
    response = requests.get(
        next_url,
        headers=zotero_headers,
        params=zotero_params,
        timeout=30
    )
    
    response_data = response.json()
    zotero_references.extend(response_data)
    
    if "Link" in response.headers:
        links = response.headers["Link"].split(', ')
        next_url = None
    
        for link in links:
            if 'rel="next"' in link:
                next_url = link.split(';')[0].strip("<>")
                break
    
    else:
        next_url = None
    
    # print("Current fetched count: %s", len(zotero_references))
    
zotero_references
# Out:
# [{'key': 'LUHNJPE5',
#   'version': 528,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/LUHNJPE5',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/LUHNJPE5',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'ASEAN', 'parsedDate': '2020', 'numChildren': 0},
#   'data': {'key': 'LUHNJPE5',
#    'version': 528,
#    'itemType': 'webpage',
#    'title': 'ASEAN Digital Masterplan 2025',
#    'creators': [{'creatorType': 'author', 'name': 'ASEAN'}],
#    'abstractNote': '',
#    'websiteTitle': 'ASEAN Main Portal',
#    'websiteType': '',
#    'date': '2020',
#    'shortTitle': '',
#    'url': 'https://asean.org/book/asean-digital-masterplan-2025/',
#    'accessDate': '2024-12-12T16:41:11Z',
#    'language': 'en-US',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['VUS9AZXW'],
#    'relations': {},
#    'dateAdded': '2024-12-12T16:41:11Z',
#    'dateModified': '2025-02-24T08:32:16Z'}},
#  {'key': 'NVMGGNJB',
#   'version': 527,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/NVMGGNJB',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/NVMGGNJB',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Bonnemere',
#    'parsedDate': '2023-12-01',
#    'numChildren': 0},
#   'data': {'key': 'NVMGGNJB',
#    'version': 527,
#    'itemType': 'webpage',
#    'title': 'The Future of Aging: AI and Robotics Are Transforming Senior Care',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Vince',
#      'lastName': 'Bonnemere'}],
#    'abstractNote': 'Discover the Future of Aging: innovations shaping a future where technology enhances the well-being and independence of older adults.',
#    'websiteTitle': 'Assisted Living Locators',
#    'websiteType': '',
#    'date': '2023-12-01',
#    'shortTitle': 'The Future of Aging',
#    'url': 'https://assistedlivinglocators.com/articles/the-future-of-aging-how-ai-and-robotics-are-transforming-senior-care',
#    'accessDate': '2025-02-22T17:11:20Z',
#    'language': 'en',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['X7AY75N7'],
#    'relations': {},
#    'dateAdded': '2025-02-22T17:11:20Z',
#    'dateModified': '2025-02-22T17:12:11Z'}},
#  {'key': 'WXPIM45I',
#   'version': 521,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/WXPIM45I',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/WXPIM45I',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Gosavi',
#    'parsedDate': '2024-09-23',
#    'numChildren': 0},
#   'data': {'key': 'WXPIM45I',
#    'version': 521,
#    'itemType': 'blogPost',
#    'title': 'Elderly Care Technology: 6 Trends Shaping Home Health in 2025',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Pratik',
#      'lastName': 'Gosavi'}],
#    'abstractNote': 'Discover how elderly care technology is revolutionizing home health care. Explore 6 top trends for 2024, from AI to smart homes and robotics.',
#    'blogTitle': 'Healthcare - Mindbowser',
#    'websiteType': '',
#    'date': '2024-09-23T09:03:40+00:00',
#    'url': 'https://healthcare.mindbowser.com/elderly-care-technology-in-home-health-care/',
#    'accessDate': '2025-02-22T17:10:58Z',
#    'language': 'en-US',
#    'shortTitle': 'Elderly Care Technology',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['X7AY75N7'],
#    'relations': {},
#    'dateAdded': '2025-02-22T17:10:58Z',
#    'dateModified': '2025-02-22T17:10:58Z'}},
#  {'key': '8N3VI3LK',
#   'version': 520,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/8N3VI3LK',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/8N3VI3LK',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Chen et al.',
#    'parsedDate': '2015',
#    'numChildren': 0},
#   'data': {'key': '8N3VI3LK',
#    'version': 520,
#    'itemType': 'journalArticle',
#    'title': 'AI’s Effects on Economic Growth in Aging Society: Induced Innovation and Labor Supplemental Substitution',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Qiulin',
#      'lastName': 'Chen'},
#     {'creatorType': 'author', 'firstName': 'Duo', 'lastName': 'Xu'},
#     {'creatorType': 'author', 'firstName': 'Yi', 'lastName': 'Zhou'}],
#    'abstractNote': '',
#    'publicationTitle': '',
#    'volume': '',
#    'issue': '',
#    'pages': '',
#    'date': '2015',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': '',
#    'DOI': '10.19602/j.chinaeconomist.2019.9.06',
#    'ISSN': '',
#    'shortTitle': '',
#    'url': '',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['X7AY75N7'],
#    'relations': {},
#    'dateAdded': '2025-02-22T17:06:23Z',
#    'dateModified': '2025-02-22T17:09:09Z'}},
#  {'key': 'H3FBNQ7U',
#   'version': 501,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/H3FBNQ7U',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/H3FBNQ7U',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Adler',
#    'parsedDate': '2024-04-25',
#    'numChildren': 0},
#   'data': {'key': 'H3FBNQ7U',
#    'version': 501,
#    'itemType': 'blogPost',
#    'title': 'The Advantages and Disadvantages of AI in Elder Care',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Bryan',
#      'lastName': 'Adler'}],
#    'abstractNote': 'For over two decades, the elder care professionals at Rothkoff Law Group have been helping clients and their families respond to the legal, financial, physical, and psychological challenges associated with the aging process in both New Jersey and Pennsylvania.',
#    'blogTitle': 'Rothkoff Law Group',
#    'websiteType': '',
#    'date': '2024-04-25T10:00:19+00:00',
#    'url': 'https://rothkofflaw.com/2024/04/25/the-advantages-and-disadvantages-of-ai-in-elder-care/',
#    'accessDate': '2025-02-22T16:57:15Z',
#    'language': 'en-US',
#    'shortTitle': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['X7AY75N7'],
#    'relations': {},
#    'dateAdded': '2025-02-22T16:57:15Z',
#    'dateModified': '2025-02-22T16:57:15Z'}},
#  {'key': 'PBVHWS4I',
#   'version': 500,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/PBVHWS4I',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/PBVHWS4I',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Martinez-Martin and Costa',
#    'parsedDate': '2021',
#    'numChildren': 0},
#   'data': {'key': 'PBVHWS4I',
#    'version': 500,
#    'itemType': 'journalArticle',
#    'title': 'Assistive Technology for Elderly Care: An Overview',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Ester',
#      'lastName': 'Martinez-Martin'},
#     {'creatorType': 'author', 'firstName': 'Angelo', 'lastName': 'Costa'}],
#    'abstractNote': 'Global demographic changes have resulted in a growing technological demand to meet the arisen social needs. In particular, the increasingly ageing population requires assistive technologies to stay at home for longer independently while receiving continuous healthcare. In this sense, a wide academic and industrial research is taking place, introducing these technologies in hospitals and rehabilitation centres. This paper aims at providing an overview of research projects for elderly care and assistance, focusing on cognitive and robot assistants due to their popularity in the area. More precisely, physical and/or cognitive rehabilitation are presented. This paper also discusses their limitations and the open challenges to be tackled in order to be successfully integrated in our society.',
#    'publicationTitle': 'IEEE Access',
#    'volume': '9',
#    'issue': '',
#    'pages': '92420-92430',
#    'date': '2021',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': '',
#    'DOI': '10.1109/ACCESS.2021.3092407',
#    'ISSN': '2169-3536',
#    'shortTitle': 'Assistive Technology for Elderly Care',
#    'url': 'https://ieeexplore.ieee.org/document/9465105',
#    'accessDate': '2025-02-22T16:56:53Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'IEEE Xplore',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'Conference Name: IEEE Access',
#    'tags': [{'tag': 'Assistive technologies', 'type': 1},
#     {'tag': 'Assistive technology', 'type': 1},
#     {'tag': 'Monitoring', 'type': 1},
#     {'tag': 'Older adults', 'type': 1},
#     {'tag': 'Robot sensing systems', 'type': 1},
#     {'tag': 'Robots', 'type': 1},
#     {'tag': 'Visualization', 'type': 1},
#     {'tag': 'Wearable sensors', 'type': 1},
#     {'tag': 'cognitive assistants', 'type': 1},
#     {'tag': 'healthcare', 'type': 1},
#     {'tag': 'robotics', 'type': 1}],
#    'collections': ['X7AY75N7'],
#    'relations': {},
#    'dateAdded': '2025-02-22T16:56:53Z',
#    'dateModified': '2025-02-22T16:56:53Z'}},
#  {'key': '8W7RTVXD',
#   'version': 499,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/8W7RTVXD',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/8W7RTVXD',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'VNEEP', 'numChildren': 0},
#   'data': {'key': '8W7RTVXD',
#    'version': 499,
#    'itemType': 'webpage',
#    'title': 'Sustainable production and energy saving at the brewery',
#    'creators': [{'creatorType': 'author',
#      'firstName': '',
#      'lastName': 'VNEEP'}],
#    'abstractNote': 'Heineken Vietnam - Hanoi Brewery has implemented energy-saving solutions during production to enhance the competitiveness of its products.',
#    'websiteTitle': '',
#    'websiteType': '',
#    'date': '',
#    'shortTitle': '',
#    'url': 'https://vneec.gov.vn/tin-tuc/news/t31625/sustainable-production-and-energy-saving-at-the-brewery',
#    'accessDate': '2025-02-18T08:11:53Z',
#    'language': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['MXS9X79T'],
#    'relations': {},
#    'dateAdded': '2025-02-18T08:11:53Z',
#    'dateModified': '2025-02-19T08:28:41Z'}},
#  {'key': '4B5H96IT',
#   'version': 498,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/4B5H96IT',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/4B5H96IT',
#     'type': 'text/html'}},
#   'meta': {'parsedDate': '2023-10-08', 'numChildren': 1},
#   'data': {'key': '4B5H96IT',
#    'version': 498,
#    'itemType': 'webpage',
#    'title': "TTWTO VCCI - Vietnam's FTAs as of October 2024",
#    'creators': [],
#    'abstractNote': '',
#    'websiteTitle': '',
#    'websiteType': '',
#    'date': '2023-10-08',
#    'shortTitle': '',
#    'url': 'https://wtocenter.vn/thong-ke/13814-vietnams-ftas-summary-as-of-april-2019',
#    'accessDate': '2025-02-17T10:56:03Z',
#    'language': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['MXS9X79T'],
#    'relations': {},
#    'dateAdded': '2025-02-17T10:56:03Z',
#    'dateModified': '2025-02-19T08:28:23Z'}},
#  {'key': 'J5GTGLES',
#   'version': 497,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/J5GTGLES',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/J5GTGLES',
#     'type': 'text/html'}},
#   'meta': {'numChildren': 1},
#   'data': {'key': 'J5GTGLES',
#    'version': 497,
#    'itemType': 'webpage',
#    'title': 'WIPO Lex',
#    'creators': [],
#    'abstractNote': '',
#    'websiteTitle': '',
#    'websiteType': '',
#    'date': '',
#    'shortTitle': '',
#    'url': 'https://www.wipo.int/wipolex/en/text/497980',
#    'accessDate': '2025-02-19T07:39:27Z',
#    'language': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['MXS9X79T'],
#    'relations': {},
#    'dateAdded': '2025-02-19T07:39:27Z',
#    'dateModified': '2025-02-19T08:28:05Z'}},
#  {'key': '3W5XB78U',
#   'version': 496,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/3W5XB78U',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/3W5XB78U',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'International Trade Administration',
#    'parsedDate': '2024-09-20',
#    'numChildren': 0},
#   'data': {'key': '3W5XB78U',
#    'version': 496,
#    'itemType': 'webpage',
#    'title': 'Vietnam - Digital Economy',
#    'creators': [{'creatorType': 'author',
#      'name': 'International Trade Administration'}],
#    'abstractNote': 'Overview of the digital economy sector, including challenges and opportunities, between the United States and Vietnam.',
#    'websiteTitle': '',
#    'websiteType': '',
#    'date': '2024-09-20',
#    'shortTitle': '',
#    'url': 'https://www.trade.gov/country-commercial-guides/vietnam-digital-economy',
#    'accessDate': '2025-02-19T08:17:19Z',
#    'language': 'en',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['MXS9X79T'],
#    'relations': {},
#    'dateAdded': '2025-02-19T08:17:19Z',
#    'dateModified': '2025-02-19T08:18:45Z'}},
#  {'key': 'I8LLNS97',
#   'version': 492,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/I8LLNS97',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/I8LLNS97',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'KPMG',
#    'parsedDate': '2017-06-19',
#    'numChildren': 0},
#   'data': {'key': 'I8LLNS97',
#    'version': 492,
#    'itemType': 'report',
#    'title': 'Tax issues under the Law on Technology Transfer 2017',
#    'creators': [{'creatorType': 'author', 'name': 'KPMG'}],
#    'abstractNote': '',
#    'reportNumber': '',
#    'reportType': '',
#    'seriesTitle': '',
#    'place': '',
#    'institution': 'KPMG',
#    'date': '2017-06-19',
#    'pages': '',
#    'language': '',
#    'shortTitle': '',
#    'url': 'https://assets.kpmg.com/content/dam/kpmg/vn/pdf/tax-alert/2017/vietnam-tax_alert-2017-issue-4-en.pdf',
#    'accessDate': '',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['MXS9X79T'],
#    'relations': {},
#    'dateAdded': '2025-02-19T07:43:14Z',
#    'dateModified': '2025-02-19T07:44:35Z'}},
#  {'key': '7FCLSGPW',
#   'version': 482,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/7FCLSGPW',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/7FCLSGPW',
#     'type': 'text/html'}},
#   'meta': {'parsedDate': '2017-07', 'numChildren': 0},
#   'data': {'key': '7FCLSGPW',
#    'version': 482,
#    'itemType': 'webpage',
#    'title': '07/2017/QH14 - Law on Technology Transfer',
#    'creators': [],
#    'abstractNote': '',
#    'websiteTitle': '',
#    'websiteType': '',
#    'date': '2017-07',
#    'shortTitle': '',
#    'url': 'https://www.most.gov.vn/en/Pages/Detaildocument.aspx?vID=45',
#    'accessDate': '2025-02-19T04:30:55Z',
#    'language': '',
#    'rights': '',
#    'extra': 'Online PDF: https://wipolex-res.wipo.int/edocs/lexdocs/laws/en/vn/vn124en.pdf',
#    'tags': [],
#    'collections': ['MXS9X79T'],
#    'relations': {},
#    'dateAdded': '2025-02-19T04:30:55Z',
#    'dateModified': '2025-02-19T04:49:12Z'}},
#  {'key': 'ANQFRM74',
#   'version': 479,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/ANQFRM74',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/ANQFRM74',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Nguyen',
#    'parsedDate': '2024-07-31',
#    'numChildren': 0},
#   'data': {'key': 'ANQFRM74',
#    'version': 479,
#    'itemType': 'webpage',
#    'title': 'Vietnam: New draft Law on Digital Technology Industry and draft Data Law',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Manh Hung Tran, Huu Tuan Nguyen, Huyen Minh Nguyen, Tuan Linh',
#      'lastName': 'Nguyen'}],
#    'abstractNote': 'The Vietnamese authorities recently released two draft laws, including the draft Data Law and the draft Law on Digital Technology Industry, for public comments. These proposed laws seek to address various issues in the fields of data and digital technology, with the potential to significantly impact businesses across various industries.',
#    'websiteTitle': 'Global Compliance News',
#    'websiteType': '',
#    'date': '2024-07-31T11:39:46+00:00',
#    'shortTitle': 'Vietnam',
#    'url': 'https://www.globalcompliancenews.com/2024/07/31/https-insightplus-bakermckenzie-com-bm-investigations-compliance-ethics-vietnam-new-draft-law-on-digital-technology-industry-and-draft-data-law_07092024/',
#    'accessDate': '2025-02-19T04:21:29Z',
#    'language': 'en-US',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['MXS9X79T'],
#    'relations': {},
#    'dateAdded': '2025-02-19T04:21:29Z',
#    'dateModified': '2025-02-19T04:21:29Z'}},
#  {'key': '9QC9DJUW',
#   'version': 477,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/9QC9DJUW',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/9QC9DJUW',
#     'type': 'text/html'}},
#   'meta': {'parsedDate': '2013-06-12', 'numChildren': 0},
#   'data': {'key': '9QC9DJUW',
#    'version': 477,
#    'itemType': 'webpage',
#    'title': 'Viet Nam’s industrial policy: Designing policies for sustainable development',
#    'creators': [],
#    'abstractNote': 'Viet Nam has made a remarkable transition since 1989 from a centrally planned economy dominated by the administrative allocation of resources to an economy l',
#    'websiteTitle': 'UNDP',
#    'websiteType': '',
#    'date': '2013-06-12',
#    'shortTitle': 'Viet Nam’s industrial policy',
#    'url': 'https://www.undp.org/vietnam/publications/viet-nams-industrial-policy-designing-policies-sustainable-development',
#    'accessDate': '2025-02-18T14:05:08Z',
#    'language': 'en',
#    'rights': '',
#    'extra': 'Online PDF: https://www.undp.org/sites/g/files/zskgke326/files/migration/vn/24721_20925_Industrial_Policy.pdf',
#    'tags': [],
#    'collections': ['MXS9X79T'],
#    'relations': {},
#    'dateAdded': '2025-02-18T14:05:08Z',
#    'dateModified': '2025-02-18T14:06:16Z'}},
#  {'key': 'EF8UEA3W',
#   'version': 468,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/EF8UEA3W',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/EF8UEA3W',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Bring',
#    'parsedDate': '2023-08-20',
#    'numChildren': 0},
#   'data': {'key': 'EF8UEA3W',
#    'version': 468,
#    'itemType': 'blogPost',
#    'title': 'A Brief History of Industrial Policy in Vietnam',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Daniel',
#      'lastName': 'Bring'}],
#    'abstractNote': 'News of an American aircraft carrier approaching Vietnam recalls a history of conflict. Yet as the USS Ronald Reagan pulled into port at Danang on June 25, 2023, she came as a sign of friendship. The visit, only the third by a U.S. aircraft carrier since the end of the Viet\xadnam War, testified to strengthening ties between the two countries. For reasons of both realpolitik and material reality...',
#    'blogTitle': 'American Affairs Journal',
#    'websiteType': '',
#    'date': '2023-08-20T04:04:00+00:00',
#    'url': 'https://americanaffairsjournal.org/2023/08/a-brief-history-of-industrial-policy-in-vietnam/',
#    'accessDate': '2025-02-18T09:24:52Z',
#    'language': 'en-US',
#    'shortTitle': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['MXS9X79T'],
#    'relations': {},
#    'dateAdded': '2025-02-18T09:24:52Z',
#    'dateModified': '2025-02-18T09:24:52Z'}},
#  {'key': 'SRBLB6BR',
#   'version': 460,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/SRBLB6BR',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/SRBLB6BR',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Le',
#    'parsedDate': '2023-10-30',
#    'numChildren': 0},
#   'data': {'key': 'SRBLB6BR',
#    'version': 460,
#    'itemType': 'blogPost',
#    'title': 'The Definitive Guide to Vietnam’s 17 Active Free Trade Agreements – FTAs',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Dahlia',
#      'lastName': 'Le'}],
#    'abstractNote': 'Vietnam has come a long way from the war-torn, underdeveloped colony, partly thanks to its 17 free trade agreements with over 50 countries and economic blocs.',
#    'blogTitle': '',
#    'websiteType': '',
#    'date': '2023-10-30T15:01:59+07:00',
#    'url': 'https://vietnam.incorp.asia/guide-to-vietnams-17-free-trade-agreements/',
#    'accessDate': '2025-02-17T10:24:44Z',
#    'language': 'en-US',
#    'shortTitle': '',
#    'rights': '',
#    'extra': 'Section: Business Blogs',
#    'tags': [],
#    'collections': ['MXS9X79T'],
#    'relations': {},
#    'dateAdded': '2025-02-17T10:24:44Z',
#    'dateModified': '2025-02-17T10:51:32Z'}},
#  {'key': 'Y6F3G6HX',
#   'version': 459,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/Y6F3G6HX',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/Y6F3G6HX',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Nguyen et al.',
#    'parsedDate': '2014',
#    'numChildren': 0},
#   'data': {'key': 'Y6F3G6HX',
#    'version': 459,
#    'itemType': 'report',
#    'title': 'UNU-WIDER : Working Paper : The Evolution of Vietnamese Industry',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Thi Tue Anh',
#      'lastName': 'Nguyen'},
#     {'creatorType': 'author', 'firstName': 'Minh Duc', 'lastName': 'Luu'},
#     {'creatorType': 'author', 'firstName': 'Duc Chieu', 'lastName': 'Trinh'}],
#    'abstractNote': 'The transfer from an import-substitution to an export-orientation strategy has been in effect in Vietnam since the reform process, Doi Moi, necessitating the reformulation of macroeconomic, trading and sectoral policies. As a result, the industry sector has experienced gradual growth as the country’s economy is becoming more open and gaining deeper integration with regional and the world economies, as exemplified by membership in the ASEAN Free Trade Area (1995) and World Trade Organization (2006). To support this integration process, the structure of the industrial sector has been changed to more appropriate since the Doi Moi. Many export processing zones, industrial zones and economic zones have been set up to attract the interest of multi-sectors, including foreign and non-state investors. Consequently, the capacity, output and productivity of the industrial sector have improved considerably. But certain policy issues also arose during the industrial development process. These can be summarized into three main problems: minimal contribution from current policies to improving competitiveness, policy failure to encourage firm restructuring, and lack of a well-coordinated framework for industrial policy.',
#    'reportNumber': 'WIDER Working Paper 2014/076',
#    'reportType': '',
#    'seriesTitle': '',
#    'place': '',
#    'institution': 'UNU-WIDER',
#    'date': '2014',
#    'pages': '',
#    'language': 'en',
#    'shortTitle': '',
#    'url': 'https://doi.org/10.35188/UNU-WIDER/2014/797-4',
#    'accessDate': '2025-02-17T10:26:09Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': '',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'PDF Link: https://www.brookings.edu/wp-content/uploads/2016/07/L2C_WP19_Nguyen-Luu-and-Trinh-1.pdf',
#    'tags': [],
#    'collections': ['MXS9X79T'],
#    'relations': {},
#    'dateAdded': '2025-02-17T10:26:09Z',
#    'dateModified': '2025-02-17T10:50:28Z'}},
#  {'key': 'BTSIYMWG',
#   'version': 444,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/BTSIYMWG',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/BTSIYMWG',
#     'type': 'text/html'}},
#   'meta': {'numChildren': 0},
#   'data': {'key': 'BTSIYMWG',
#    'version': 444,
#    'itemType': 'webpage',
#    'title': 'Summary report 8–9 March 2006',
#    'creators': [],
#    'abstractNote': '',
#    'websiteTitle': 'IISD Earth Negotiations Bulletin',
#    'websiteType': '',
#    'date': '',
#    'shortTitle': '',
#    'url': 'http://enb.iisd.org/events/2006-climate-technology-initiative-cti-industry-joint-seminar-successful-cases-technology-0',
#    'accessDate': '2025-02-05T13:31:15Z',
#    'language': 'en',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['MXS9X79T'],
#    'relations': {},
#    'dateAdded': '2025-02-05T13:31:15Z',
#    'dateModified': '2025-02-05T13:31:15Z'}},
#  {'key': 'P9UZ9SLT',
#   'version': 441,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/P9UZ9SLT',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/P9UZ9SLT',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'van Kolfschooten',
#    'parsedDate': '2023-07-01',
#    'numChildren': 0},
#   'data': {'key': 'P9UZ9SLT',
#    'version': 441,
#    'itemType': 'journalArticle',
#    'title': 'The AI cycle of health inequity and digital ageism: mitigating biases through the EU regulatory framework on medical devices',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Hannah',
#      'lastName': 'van Kolfschooten'}],
#    'abstractNote': 'The use of Artificial Intelligence (AI) medical devices is rapidly growing. Although AI may benefit the quality and safety of healthcare for older adults, it simultaneously introduces new ethical and legal issues. Many AI medical devices exhibit age-related biases. The first part of this paper explains how ‘digital ageism’ is produced throughout the entire lifecycle of medical AI and may lead to health inequity for older people: systemic, avoidable differences in the health status of different population groups. This paper takes digital ageism as a use case to show the potential inequitable effects of AI, conceptualized as the ‘AI cycle of health inequity’. The second part of this paper explores how the European Union (EU) regulatory framework addresses the issue of digital ageism. It argues that the negative effects of age-related bias in AI medical devices are insufficiently recognized within the regulatory framework of the EU Medical Devices Regulation and the new AI Act. It concludes that while the EU framework does address some of the key issues related to technical biases in AI medical devices by stipulating rules for performance and data quality, it does not account for contextual biases, therefore neglecting part of the AI cycle of health inequity.',
#    'publicationTitle': 'Journal of Law and the Biosciences',
#    'volume': '10',
#    'issue': '2',
#    'pages': 'lsad031',
#    'date': '2023-07-01',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'Journal of Law and the Biosciences',
#    'language': '',
#    'DOI': '10.1093/jlb/lsad031',
#    'ISSN': '2053-9711',
#    'shortTitle': 'The AI cycle of health inequity and digital ageism',
#    'url': 'https://doi.org/10.1093/jlb/lsad031',
#    'accessDate': '2025-02-01T00:21:20Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'Silverchair',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['AZYQMZYU'],
#    'relations': {},
#    'dateAdded': '2025-02-01T00:21:20Z',
#    'dateModified': '2025-02-01T00:21:23Z'}},
#  {'key': '7VQBYT8E',
#   'version': 439,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/7VQBYT8E',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/7VQBYT8E',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Schmitz et al.',
#    'parsedDate': '2012',
#    'numChildren': 0},
#   'data': {'key': '7VQBYT8E',
#    'version': 439,
#    'itemType': 'journalArticle',
#    'title': "Who Drives Economic Reform in Vietnam's Provinces?",
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Hubert',
#      'lastName': 'Schmitz'},
#     {'creatorType': 'author', 'firstName': 'Dau Anh', 'lastName': 'Tuan'},
#     {'creatorType': 'author', 'firstName': 'Pham Thi Thu', 'lastName': 'Hang'},
#     {'creatorType': 'author', 'firstName': 'Neil', 'lastName': 'McCulloch'}],
#    'abstractNote': "Vietnam keeps surprising the world with the speed and depth of its economic transformation. This research report suggests that the decentralisation of certain economic powers from central to provincial government has contributed to this success. Allowing provinces to find their own way forward was central to Vietnam's progress in institutional and economic development. Decentralisation brought about a number of inefficiencies, but these are outweighed by the gains resulting from policy experimentation at the provincial level. The main question of the report is who drives the economic reform process in the provinces, exploring the role of business and government and alliances between the two. This is a difficult undertaking because it involves dipping into sensitive issues of state-business relations and because there are enormous variations between provinces and over time. Key to the feasibility of this project was the collaboration of IDS with the Vietnam Chamber of Commerce and Industry (VCCI). VCCI is an influential organisation with strong connections to business, government and the Communist Party. These connections are essential for access to political and business leaders and for understanding the economic reform process from private and public perspectives. Provincial government is by necessity involved in the economic reform process, but who is actually driving it? The research shows that in those provinces which are making most progress in economic reform, the private sector played an important role. Not against government but with government. There was no formal public-private coalition but the dynamic was one of proactive government seeking the input from the private sector, and the latter lobbying for and contributing to responsive and effective government. Both national and foreign enterprises played a role but small enterprises tended to be marginalised from the process. Some of the best insights come from comparing provinces and observing how different alignments of interest influenced the reform process.",
#    'publicationTitle': 'IDS Research Reports',
#    'volume': '2012',
#    'issue': '76',
#    'pages': '01-89',
#    'date': '2012',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': 'en',
#    'DOI': '10.1111/j.2040-0217.2012.00076_2.x',
#    'ISSN': '2040-0217',
#    'shortTitle': '',
#    'url': 'https://onlinelibrary.wiley.com/doi/abs/10.1111/j.2040-0217.2012.00076_2.x',
#    'accessDate': '2025-01-31T00:54:48Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'Wiley Online Library',
#    'callNumber': '',
#    'rights': '© 2012 Institute of Development Studies',
#    'extra': "_eprint: https://onlinelibrary.wiley.com/doi/pdf/10.1111/j.2040-0217.2012.00076_2.x\n\nOnline PDF: https://www.researchgate.net/publication/261535497_Who_Drives_Economic_Reform_in_Vietnam's_Provinces",
#    'tags': [{'tag': 'Vietnam', 'type': 1},
#     {'tag': 'decentralisation', 'type': 1},
#     {'tag': 'economic governance', 'type': 1},
#     {'tag': 'economic reform', 'type': 1},
#     {'tag': 'investment climate', 'type': 1},
#     {'tag': 'private sector', 'type': 1},
#     {'tag': 'provincial government', 'type': 1},
#     {'tag': 'state business relations', 'type': 1}],
#    'collections': ['MXS9X79T'],
#    'relations': {},
#    'dateAdded': '2025-01-31T00:54:48Z',
#    'dateModified': '2025-01-31T00:55:33Z'}},
#  {'key': 'MMWJSNJH',
#   'version': 435,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/MMWJSNJH',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/MMWJSNJH',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Gomathy et al.',
#    'parsedDate': '2024-09-25',
#    'numChildren': 2},
#   'data': {'key': 'MMWJSNJH',
#    'version': 435,
#    'itemType': 'journalArticle',
#    'title': 'Ethical Implications of Cybersecurity Breaches and Data Privacy Violations',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Dr. C.K',
#      'lastName': 'Gomathy'},
#     {'creatorType': 'author', 'firstName': 'Dr.V', 'lastName': 'Geetha'},
#     {'creatorType': 'author', 'firstName': 'Mr.S', 'lastName': 'Aravind'},
#     {'creatorType': 'author', 'firstName': 'V.Venkata', 'lastName': 'Surya'}],
#    'abstractNote': 'The increasing reliance on digital technology has led to a surge in cybersecurity breaches and data privacy violations. These incidents raise significant ethical concerns, impacting individuals, organizations, and society as a whole. This paper explores the ethical ramifications of such breaches, focusing on issues like privacy intrusion, potential harm to individuals, and the erosion of trust. It further examines the ethical obligations of organizations in data collection, storage, and security practices. Finally, the paper discusses potential solutions and approaches to mitigate these ethical concerns and promote a more responsible digital ecosystem  Keywords:Cybersecurity, Data Privacy, Ethical Implications, Privacy Intrusion, Trust, Data Security',
#    'publicationTitle': 'INTERANTIONAL JOURNAL OF SCIENTIFIC RESEARCH IN ENGINEERING AND MANAGEMENT',
#    'volume': '08',
#    'issue': '09',
#    'pages': '1-5',
#    'date': '2024-09-25',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'IJSREM',
#    'language': '',
#    'DOI': '10.55041/IJSREM37506',
#    'ISSN': '25823930',
#    'shortTitle': '',
#    'url': 'https://ijsrem.com/download/ethical-implications-of-cybersecurity-breaches-and-data-privacy-violations/',
#    'accessDate': '2025-01-26T09:34:57Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'Semantic Scholar',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [],
#    'collections': ['EPGK5DFF'],
#    'relations': {},
#    'dateAdded': '2025-01-26T09:34:57Z',
#    'dateModified': '2025-01-27T16:25:11Z'}},
#  {'key': '2HZNY8AM',
#   'version': 431,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/2HZNY8AM',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/2HZNY8AM',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Macnish and van der Ham',
#    'parsedDate': '2020-11-01',
#    'numChildren': 0},
#   'data': {'key': '2HZNY8AM',
#    'version': 431,
#    'itemType': 'journalArticle',
#    'title': 'Ethics in cybersecurity research and practice',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Kevin',
#      'lastName': 'Macnish'},
#     {'creatorType': 'author',
#      'firstName': 'Jeroen',
#      'lastName': 'van der Ham'}],
#    'abstractNote': 'This paper critiques existing governance in cyber-security ethics through providing an overview of some of the ethical issues facing researchers in the cybersecurity community and highlighting shortfalls in governance practice. We separate these issues into those facing the academic research community and those facing the (corporate) practitioner community, drawing on two case studies. While there is overlap between these communities, there are also stark differences. Academic researchers can often rely on research ethics boards (REBs) to provide ethical oversight and governance which are typically unavailable to the practitioner community. However, we argue that even within the academic community the constitution of REBs is such that they may be (and in some cases at least are) unable to offer sound advice. Our recommendations are that ethics should be taught in far greater depth on computer science courses than is currently the case, and that codes of conduct should be developed and deployed provided they can be seen to be effective. In tandem with these, an active discussion regarding the ethics of cybersecurity and cybersecurity research is urgently needed.',
#    'publicationTitle': 'Technology in Society',
#    'volume': '63',
#    'issue': '',
#    'pages': '101382',
#    'date': '2020-11-01',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'Technology in Society',
#    'language': '',
#    'DOI': '10.1016/j.techsoc.2020.101382',
#    'ISSN': '0160-791X',
#    'shortTitle': '',
#    'url': 'https://www.sciencedirect.com/science/article/pii/S0160791X19306840',
#    'accessDate': '2025-01-26T09:45:41Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'ScienceDirect',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [{'tag': 'Cybersecurity', 'type': 1},
#     {'tag': 'Discrimination', 'type': 1},
#     {'tag': 'Ethics', 'type': 1},
#     {'tag': 'IRB', 'type': 1},
#     {'tag': 'Personal data', 'type': 1},
#     {'tag': 'Privacy', 'type': 1},
#     {'tag': 'Research', 'type': 1},
#     {'tag': 'Trust', 'type': 1}],
#    'collections': ['EPGK5DFF'],
#    'relations': {},
#    'dateAdded': '2025-01-26T09:45:41Z',
#    'dateModified': '2025-01-26T09:45:41Z'}},
#  {'key': 'FFYVQUUP',
#   'version': 430,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/FFYVQUUP',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/FFYVQUUP',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Allahrakha',
#    'parsedDate': '2023-07-28',
#    'numChildren': 0},
#   'data': {'key': 'FFYVQUUP',
#    'version': 430,
#    'itemType': 'journalArticle',
#    'title': 'Balancing Cyber-security and Privacy: Legal and Ethical Considerations in the Digital Age',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Naeem',
#      'lastName': 'Allahrakha'}],
#    'abstractNote': 'In today’s digital world the need to maintain cyber-security and protect sensitive information is more important than ever. However, this must be balanced against the right to privacy, which is also a fundamental human right. This article provides an overview of the legal and ethical considerations involved in balancing cyber-security and privacy in the digital age. It explores the challenges of implementing effective cyber-security measures while respecting privacy rights, and discusses the current legal framework for cyber-security and privacy in various jurisdictions. The article also considers the ethical implications of balancing these two important values and suggests ways in which cyber-security and privacy concerns can be reconciled in a general context. By highlighting the importance of a careful balance between cyber-security and privacy, this article aims to raise awareness of the need for ethical and legal considerations in the development of digital technologies and their regulation.',
#    'publicationTitle': 'Legal Issues in the Digital Age',
#    'volume': '4',
#    'issue': '2',
#    'pages': '78-121',
#    'date': '2023-07-28',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': 'en',
#    'DOI': '10.17323/10.17323/2713-2749.2023.2.78.121',
#    'ISSN': '2713-2749',
#    'shortTitle': 'Balancing Cyber-security and Privacy',
#    'url': 'https://lida.hse.ru/article/view/17666',
#    'accessDate': '2025-01-26T09:36:42Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'lida.hse.ru',
#    'callNumber': '',
#    'rights': 'Copyright (c)',
#    'extra': 'Number: 2',
#    'tags': [{'tag': 'cyber-security', 'type': 1},
#     {'tag': 'digital age', 'type': 1},
#     {'tag': 'ethical considerations', 'type': 1},
#     {'tag': 'legal considerations', 'type': 1},
#     {'tag': 'privacy', 'type': 1}],
#    'collections': ['EPGK5DFF'],
#    'relations': {},
#    'dateAdded': '2025-01-26T09:36:42Z',
#    'dateModified': '2025-01-26T09:36:42Z'}},
#  {'key': 'ZB8CVUX6',
#   'version': 426,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/ZB8CVUX6',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/ZB8CVUX6',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Path', 'parsedDate': '2020', 'numChildren': 0},
#   'data': {'key': 'ZB8CVUX6',
#    'version': 426,
#    'itemType': 'book',
#    'title': "Vietnam's Strategic Thinking during the Third Indochina War",
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Kosal',
#      'lastName': 'Path'}],
#    'abstractNote': 'When costly efforts to cement a strategic partnership with the Soviet Union failed, the combined political pressure of economic\ncrisis at home and imminent external threats posed by a\nSino-Cambodian alliance compelled Hanoi to reverse course. Moving away from the Marxist-Leninist ideology that had prevailed during the last decade of the Cold War era, the Vietnamese government\nimplemented broad  <i>doi moi</i>  ("renovation") reforms intended to create a peaceful regional environment for the country\'s\nintegration into the global economy. In contrast to earlier\nstudies, Path traces the moving target of these changing policy\npriorities, providing a vital addition to existing scholarship on asymmetric wartime decision-making and alliance formation among\nsmall states. The result uncovers how this critical period had\nlasting implications for the ways Vietnam continues to conduct\nitself on the global stage.',
#    'series': '',
#    'seriesNumber': '',
#    'volume': '',
#    'numberOfVolumes': '',
#    'edition': '',
#    'place': '',
#    'publisher': 'University of Wisconsin Press',
#    'date': '2020',
#    'numPages': '',
#    'language': '',
#    'ISBN': '978-0-299-32270-0',
#    'shortTitle': '',
#    'url': 'https://www.jstor.org/stable/j.ctvvsqc44',
#    'accessDate': '2025-01-25T01:45:11Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'JSTOR',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'DOI: 10.2307/j.ctvvsqc44',
#    'tags': [],
#    'collections': ['MXS9X79T'],
#    'relations': {},
#    'dateAdded': '2025-01-25T01:45:11Z',
#    'dateModified': '2025-01-25T01:45:11Z'}},
#  {'key': 'MXZDULIY',
#   'version': 423,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/MXZDULIY',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/MXZDULIY',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Mohamed Zaidi et al.',
#    'parsedDate': '2024-08-01',
#    'numChildren': 0},
#   'data': {'key': 'MXZDULIY',
#    'version': 423,
#    'itemType': 'journalArticle',
#    'title': 'Suspicious Human Activity Recognition From Surveillance Videos Using Deep Learning',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Monji',
#      'lastName': 'Mohamed Zaidi'},
#     {'creatorType': 'author',
#      'firstName': 'Gabriel',
#      'lastName': 'Avelino Sampedro'},
#     {'creatorType': 'author', 'firstName': 'Ahmad', 'lastName': 'Almadhor'},
#     {'creatorType': 'author', 'firstName': 'Shtwai', 'lastName': 'Alsubai'},
#     {'creatorType': 'author',
#      'firstName': 'Abdullah',
#      'lastName': 'Al Hejaili'},
#     {'creatorType': 'author', 'firstName': 'Michal', 'lastName': 'Gregus'},
#     {'creatorType': 'author', 'firstName': 'Sidra', 'lastName': 'Abbas'}],
# ...
#    'ISSN': '2168-2208',
#    'shortTitle': 'Large AI Models in Health Informatics',
#    'url': 'https://ieeexplore.ieee.org/document/10261199',
#    'accessDate': '2024-12-11T08:27:57Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'IEEE Xplore',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'Conference Name: IEEE Journal of Biomedical and Health Informatics',
#    'tags': [{'tag': 'Artificial intelligence', 'type': 1},
#     {'tag': 'Bioinformatics', 'type': 1},
#     {'tag': 'Biological system modeling', 'type': 1},
#     {'tag': 'Chatbots', 'type': 1},
#     {'tag': 'Data models', 'type': 1},
#     {'tag': 'Medical diagnostic imaging', 'type': 1},
#     {'tag': 'Task analysis', 'type': 1},
#     {'tag': 'bioinformatics', 'type': 1},
#     {'tag': 'biomedicine', 'type': 1},
#     {'tag': 'deep learning', 'type': 1},
#     {'tag': 'foundation model', 'type': 1},
#     {'tag': 'health informatics', 'type': 1},
#     {'tag': 'healthcare', 'type': 1},
#     {'tag': 'medical imaging', 'type': 1}],
#    'collections': ['VUS9AZXW'],
#    'relations': {},
#    'dateAdded': '2024-12-11T08:27:57Z',
#    'dateModified': '2024-12-11T08:27:57Z'}},
#  {'key': 'J7NJ2JTJ',
#   'version': 93,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/J7NJ2JTJ',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/J7NJ2JTJ',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Henman',
#    'parsedDate': '2020-10-01',
#    'numChildren': 0},
#   'data': {'key': 'J7NJ2JTJ',
#    'version': 93,
#    'itemType': 'journalArticle',
#    'title': 'Improving public services using artificial intelligence: possibilities, pitfalls, governance',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Paul',
#      'lastName': 'Henman'}],
#    'abstractNote': 'Artificial intelligence arising from the use of machine learning is rapidly being developed and deployed by governments to enhance operations, public services, and compliance and security activities. This article reviews how artificial intelligence is being used in public sector for automated decision making, for chatbots to provide information and advice, and for public safety and security. It then outlines four public administration challenges to deploying artificial intelligence in public administration: accuracy, bias and discrimination; legality, due process and administrative justice; responsibility, accountability, transparency and explainability; and power, compliance and control. The article outlines technological and governance innovations that are being developed to address these challenges.',
#    'publicationTitle': 'Asia Pacific Journal of Public Administration',
#    'volume': '42',
#    'issue': '4',
#    'pages': '209-221',
#    'date': '2020-10-01',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': '',
#    'DOI': '10.1080/23276665.2020.1816188',
#    'ISSN': '2327-6665',
#    'shortTitle': 'Improving public services using artificial intelligence',
#    'url': 'https://doi.org/10.1080/23276665.2020.1816188',
#    'accessDate': '2024-12-11T07:55:14Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'Taylor and Francis+NEJM',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'Publisher: Routledge\n_eprint: https://doi.org/10.1080/23276665.2020.1816188',
#    'tags': [{'tag': 'algorithms', 'type': 1},
#     {'tag': 'artificial intelligence (AI)', 'type': 1},
#     {'tag': 'automated decision making', 'type': 1},
#     {'tag': 'chatbots', 'type': 1},
#     {'tag': 'digital government', 'type': 1},
#     {'tag': 'ethical AI', 'type': 1}],
#    'collections': ['VUS9AZXW'],
#    'relations': {},
#    'dateAdded': '2024-12-11T07:55:14Z',
#    'dateModified': '2024-12-11T07:55:14Z'}},
#  {'key': '35HHMBWR',
#   'version': 85,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/35HHMBWR',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/35HHMBWR',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Zhao and Li',
#    'parsedDate': '2024-04-22',
#    'numChildren': 0},
#   'data': {'key': '35HHMBWR',
#    'version': 85,
#    'itemType': 'journalArticle',
#    'title': "Opportunities and challenges of integrating artificial intelligence in China's elderly care services",
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Yongyan',
#      'lastName': 'Zhao'},
#     {'creatorType': 'author', 'firstName': 'Jian', 'lastName': 'Li'}],
#    'abstractNote': "The challenge of elderly care presents a formidable task, demanding the collective attention of governmental bodies and diverse sectors of society. The integration of Artificial Intelligence (AI) into the research and development of Social Elderly Care Service (ECS) has emerged as a dominant trend, holding substantial importance in the establishment of an efficient ECS system. This study aims to serve as a comprehensive reference for the advancement of China's ECS system, achieved through the harmonious integration of a social ECS system with AI capabilities. This paper introduces the fundamental theory of AI, delving into the intricacies of the greyscale model of AI. Furthermore, it provides an overview of the current landscape of elderly care and elder care institutions, offering scientific data and insights to propel further research on AI development and system construction. Through an analysis of the existing research status, the study identifies prevalent issues within the AI-ECS integration, emphasizing pivotal factors influencing the construction of a robust social ECS system. To address these concerns, the study puts forth specific and viable policy recommendations. Notably, the questionnaire's statistics underscore that 83% of the elderly populace would opt for AI-driven solutions in selecting intelligent products, thereby underscoring the pivotal role of AI within the social ECS system. The challenges facing elderly care systems, including demographic shifts, resource constraints, and evolving societal norms, demand innovative solutions for providing efficient and effective care. This study addresses these challenges by exploring the integration of Artificial Intelligence (AI) into Social Elderly Care Services (ECS) in China. By delving into the theory of AI and assessing the existing research status, the study identifies key issues in AI-ECS integration and proposes viable policy recommendations. Insights from stakeholder surveys further highlight the importance of AI-driven solutions in meeting the needs of the elderly population.",
#    'publicationTitle': 'Scientific Reports',
#    'volume': '14',
#    'issue': '1',
#    'pages': '9254',
#    'date': '2024-04-22',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'Sci Rep',
#    'language': 'en',
#    'DOI': '10.1038/s41598-024-60067-w',
#    'ISSN': '2045-2322',
#    'shortTitle': '',
#    'url': 'https://doi.org/10.1038/s41598-024-60067-w',
#    'accessDate': '2024-12-09T09:42:02Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'Springer Link',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [{'tag': 'Artificial Intelligence', 'type': 1},
#     {'tag': 'Artificial intelligence', 'type': 1},
#     {'tag': 'Community', 'type': 1},
#     {'tag': 'Health services', 'type': 1},
#     {'tag': 'Service evaluation', 'type': 1},
#     {'tag': 'Service system', 'type': 1},
#     {'tag': 'Social pension', 'type': 1},
#     {'tag': 'Weight management', 'type': 1}],
#    'collections': ['X7AY75N7'],
#    'relations': {'dc:replaces': 'http://zotero.org/users/15574376/items/Q54DNCI9'},
#    'dateAdded': '2024-12-09T09:42:02Z',
#    'dateModified': '2024-12-10T14:42:55Z'}},
#  {'key': 'NPUSW9LH',
#   'version': 88,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/NPUSW9LH',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/NPUSW9LH',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Wang et al.',
#    'parsedDate': '2023-08-02',
#    'numChildren': 0},
#   'data': {'key': 'NPUSW9LH',
#    'version': 88,
#    'itemType': 'journalArticle',
#    'title': 'Artificial intelligence enhanced sensors - enabling technologies to next-generation healthcare and biomedical platform',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Chan',
#      'lastName': 'Wang'},
#     {'creatorType': 'author', 'firstName': 'Tianyiyi', 'lastName': 'He'},
#     {'creatorType': 'author', 'firstName': 'Hong', 'lastName': 'Zhou'},
#     {'creatorType': 'author', 'firstName': 'Zixuan', 'lastName': 'Zhang'},
#     {'creatorType': 'author', 'firstName': 'Chengkuo', 'lastName': 'Lee'}],
#    'abstractNote': 'The fourth industrial revolution has led to the development and application of health monitoring sensors that are characterized by digitalization and intelligence. These sensors have extensive applications in medical care, personal health management, elderly care, sports, and other fields, providing people with more convenient and real-time health services. However, these sensors face limitations such as noise and drift, difficulty in extracting useful information from large amounts of data, and lack of feedback or control signals. The development of artificial intelligence has provided powerful tools and algorithms for data processing and analysis, enabling intelligent health monitoring, and achieving high-precision predictions and decisions. By integrating the Internet of Things, artificial intelligence, and health monitoring sensors, it becomes possible to realize a closed-loop system with the functions of real-time monitoring, data collection, online analysis, diagnosis, and treatment recommendations. This review focuses on the development of healthcare artificial sensors enhanced by intelligent technologies from the aspects of materials, device structure, system integration, and application scenarios. Specifically, this review first introduces the great advances in wearable sensors for monitoring respiration rate, heart rate, pulse, sweat, and tears; implantable sensors for cardiovascular care, nerve signal acquisition, and neurotransmitter monitoring; soft wearable electronics for precise therapy. Then, the recent advances in volatile organic compound detection are highlighted. Next, the current developments of human-machine interfaces, AI-enhanced multimode sensors, and AI-enhanced self-sustainable systems are reviewed. Last, a perspective on future directions for further research development is also provided. In summary, the fusion of artificial intelligence and artificial sensors will provide more intelligent, convenient, and secure services for next-generation healthcare and biomedical applications.',
#    'publicationTitle': 'Bioelectronic Medicine',
#    'volume': '9',
#    'issue': '1',
#    'pages': '17',
#    'date': '2023-08-02',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': 'Bioelectronic Medicine',
#    'language': '',
#    'DOI': '10.1186/s42234-023-00118-1',
#    'ISSN': '2332-8886',
#    'shortTitle': '',
#    'url': 'https://doi.org/10.1186/s42234-023-00118-1',
#    'accessDate': '2024-12-10T08:15:32Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'BioMed Central',
#    'callNumber': '',
#    'rights': '',
#    'extra': '',
#    'tags': [{'tag': 'Artificial', 'type': 1},
#     {'tag': 'Artificial intelligence of things', 'type': 1},
#     {'tag': 'Healthcare', 'type': 1},
#     {'tag': 'Human-machine interfaces', 'type': 1},
#     {'tag': 'Implantable sensors', 'type': 1},
#     {'tag': 'Neural interfaces', 'type': 1},
#     {'tag': 'Volatile organic compounds', 'type': 1},
#     {'tag': 'Wearable sensors', 'type': 1}],
#    'collections': ['X7AY75N7'],
#    'relations': {},
#    'dateAdded': '2024-12-10T08:15:32Z',
#    'dateModified': '2024-12-10T08:15:32Z'}},
#  {'key': 'YXRHHIAF',
#   'version': 88,
#   'library': {'type': 'user',
#    'id': 15574376,
#    'name': 'monireachtang',
#    'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang',
#      'type': 'text/html'}}},
#   'links': {'self': {'href': 'https://api.zotero.org/users/15574376/items/YXRHHIAF',
#     'type': 'application/json'},
#    'alternate': {'href': 'https://www.zotero.org/monireachtang/items/YXRHHIAF',
#     'type': 'text/html'}},
#   'meta': {'creatorSummary': 'Choi et al.',
#    'parsedDate': '2022-06',
#    'numChildren': 0},
#   'data': {'key': 'YXRHHIAF',
#    'version': 88,
#    'itemType': 'journalArticle',
#    'title': 'Ethical Use of Web-Based Welfare Technology for Caring Elderly People Who Live Alone in Korea: A Case Study',
#    'creators': [{'creatorType': 'author',
#      'firstName': 'Soyun',
#      'lastName': 'Choi'},
#     {'creatorType': 'author', 'firstName': 'Kyungsook', 'lastName': 'Kim'},
#     {'creatorType': 'author', 'firstName': 'Chayapol', 'lastName': 'Kamyod'},
#     {'creatorType': 'author', 'firstName': 'Cheong Ghil', 'lastName': 'Kim'}],
#    'abstractNote': 'This study examined ethical ways to use welfare technology in a situation where the demand for non-face-to-face welfare services using Cloud based healthcare systems had increased rapidly in caring for elderly people who live alone. Through focus group interviews with social workers related to the care of elderly people who live alone, in-depth interviews were conducted on the current situation, problems, ethical issues, and development directions arising in the implementation of welfare technology. The main areas of interest were focused on improving safety in caring them using IoT technology and enhancing emotional support in preventing lonely deaths using companion robot and AI speaker. Issues such as the need for individualization, client-centeredness, privacy, self-determination, competence, informed consent, right to know, convenience, and advocacy were identified as important ethical considerations related to use of welfare technology. The research results suggested that various stakeholders should participate in the development of ethical indicators and welfare technology for the ethical use of welfare technology.',
#    'publicationTitle': 'Journal of Web Engineering',
#    'volume': '21',
#    'issue': '4',
#    'pages': '1239-1264',
#    'date': '2022-06',
#    'series': '',
#    'seriesTitle': '',
#    'seriesText': '',
#    'journalAbbreviation': '',
#    'language': '',
#    'DOI': '10.13052/jwe1540-9589.21410',
#    'ISSN': '1544-5976',
#    'shortTitle': 'Ethical Use of Web-Based Welfare Technology for Caring Elderly People Who Live Alone in Korea',
#    'url': 'https://ieeexplore.ieee.org/document/10246910',
#    'accessDate': '2024-12-09T14:57:22Z',
#    'archive': '',
#    'archiveLocation': '',
#    'libraryCatalog': 'IEEE Xplore',
#    'callNumber': '',
#    'rights': '',
#    'extra': 'Conference Name: Journal of Web Engineering',
#    'tags': [{'tag': 'AI', 'type': 1},
#     {'tag': 'Ethics', 'type': 1},
#     {'tag': 'Interviews', 'type': 1},
#     {'tag': 'IoT', 'type': 1},
#     {'tag': 'Medical services', 'type': 1},
#     {'tag': 'Older adults', 'type': 1},
#     {'tag': 'Privacy', 'type': 1},
#     {'tag': 'Safety', 'type': 1},
#     {'tag': 'Stakeholders', 'type': 1},
#     {'tag': 'Welfare technology', 'type': 1},
#     {'tag': 'community care', 'type': 1},
#     {'tag': 'elderly people who live alone', 'type': 1},
#     {'tag': 'ethical indicators', 'type': 1}],
#    'collections': ['X7AY75N7'],
#    'relations': {},
#    'dateAdded': '2024-12-09T14:57:22Z',
#    'dateModified': '2024-12-09T14:57:22Z'}}]

# %%
# Fetch zotero collections

zotero_collections_url = zotero_base_url + "/collections"
zotero_collections = {}

def fetch_zotero_collections():
    base_url = zotero_collections_url
    
    response = requests.get(
        base_url,
        headers=zotero_headers,
        params=zotero_params,
        timeout=30,
    )
    
    response_data = response.json()
    
    # print(response_data)
    # # Output: [{'key': 'ZY4P7TXF', 'version': 281, 'library': {'type': 'user', 'id': 15574376, 'name': 'monireachtang', 'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/15574376/collections/ZY4P7TXF', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/monireachtang/collections/ZY4P7TXF', 'type': 'text/html'}}, 'meta': {'numCollections': 0, 'numItems': 2}, 'data': {'key': 'ZY4P7TXF', 'version': 281, 'name': 'Family', 'parentCollection': False, 'relations': {}}}, {'key': 'AZYQMZYU', 'version': 214, 'library': {'type': 'user', 'id': 15574376, 'name': 'monireachtang', 'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/15574376/collections/AZYQMZYU', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/monireachtang/collections/AZYQMZYU', 'type': 'text/html'}}, 'meta': {'numCollections': 0, 'numItems': 9}, 'data': {'key': 'AZYQMZYU', 'version': 214, 'name': 'Academic Writing', 'parentCollection': False, 'relations': {}}}, {'key': 'EPGK5DFF', 'version': 156, 'library': {'type': 'user', 'id': 15574376, 'name': 'monireachtang', 'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/15574376/collections/EPGK5DFF', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/monireachtang/collections/EPGK5DFF', 'type': 'text/html'}}, 'meta': {'numCollections': 0, 'numItems': 33}, 'data': {'key': 'EPGK5DFF', 'version': 156, 'name': 'Philosophy of Technology', 'parentCollection': False, 'relations': {}}}, {'key': 'VUS9AZXW', 'version': 56, 'library': {'type': 'user', 'id': 15574376, 'name': 'monireachtang', 'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/15574376/collections/VUS9AZXW', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/monireachtang/collections/VUS9AZXW', 'type': 'text/html'}}, 'meta': {'numCollections': 0, 'numItems': 10}, 'data': {'key': 'VUS9AZXW', 'version': 56, 'name': 'Public Sector Innovation', 'parentCollection': False, 'relations': {}}}, {'key': 'MXS9X79T', 'version': 54, 'library': {'type': 'user', 'id': 15574376, 'name': 'monireachtang', 'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/15574376/collections/MXS9X79T', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/monireachtang/collections/MXS9X79T', 'type': 'text/html'}}, 'meta': {'numCollections': 0, 'numItems': 18}, 'data': {'key': 'MXS9X79T', 'version': 54, 'name': 'Tech Transfer', 'parentCollection': False, 'relations': {}}}, {'key': 'X7AY75N7', 'version': 53, 'library': {'type': 'user', 'id': 15574376, 'name': 'monireachtang', 'links': {'alternate': {'href': 'https://www.zotero.org/monireachtang', 'type': 'text/html'}}}, 'links': {'self': {'href': 'https://api.zotero.org/users/15574376/collections/X7AY75N7', 'type': 'application/json'}, 'alternate': {'href': 'https://www.zotero.org/monireachtang/collections/X7AY75N7', 'type': 'text/html'}}, 'meta': {'numCollections': 0, 'numItems': 38}, 'data': {'key': 'X7AY75N7', 'version': 53, 'name': 'AI', 'parentCollection': False, 'relations': {}}}]
    
    if response.status_code == 200 and response_data:
        for collection in response_data:
            if(
                isinstance(collection, dict)
                and "key" in collection
                and "data" in collection
                and isinstance(collection["data"], dict)
                and "name" in collection["data"]
            ):
                zotero_collections[collection["key"]] = collection["data"]["name"]
    else:
        print("Some Errors Exist.")

fetch_zotero_collections()
zotero_collections
# Out:
# {'ZY4P7TXF': 'Family',
#  'AZYQMZYU': 'Academic Writing',
#  'EPGK5DFF': 'Philosophy of Technology',
#  'VUS9AZXW': 'Public Sector Innovation',
#  'MXS9X79T': 'Tech Transfer',
#  'X7AY75N7': 'AI'}

# %%
# Add reference to notion

def find_matching_notion_page_id(title: str, zotero_collection_names: list) -> Optional[str]:
    
    notion_search_url: str = f"{notion_base_url}/databases/{notion_db_id}/query"
    
    # Construction filters for each zotero_collection_names
    collection_filters: list = []
    
    if zotero_collection_names:
        collection_filters = [
            {
                "property": nt_collections,
                "multi_select": {"contains": name}
            } for name in zotero_collection_names if name 
        ]
    # Build the payload to check for a title match and at least one collection match
    search_payload = {
        "filter": {
            "and": [
                {
                    "property": nt_title,
                    "title": {"equals": title}
                }
            ]
        }
    }

    # Add the collection_filters only if it is not empty, since the "or" expects a non-empty list of filters
    if collection_filters:
        search_payload["filter"]["and"].append({"or": collection_filters})
        
    try:
        response = requests.post(
            notion_search_url,
            headers=notion_headers,
            data=json.dumps(search_payload),
            timeout=30,
        )
        response_data = response.json()
    except ValueError:
        return None
    except Exception as e:
        raise
    
    if response.status_code == 200 and response_data:
        # Check if the result is a dictionary and has the required key
        if (
            isinstance(response_data, dict)
            and "results" in response_data
            and isinstance(response_data["results"], list)
        ):
            results = response_data["results"]
        
        if len(results) > 1:
            print(
                "Multiple entries found for title: '%s' and collections: '%s'. Returning the first match.",
                title, 
                zotero_collection_names
            )
            
        # If a result is found, return the page ID for updating the notion database
        if results:
            return results[0]["id"]
        
    return None

def format_authors(creators: list) -> Optional[str]:
    ...

def parse_date(date_str: str) -> Optional[str]:
    return None

def process_abstract(reference: dict) -> Optional[str]:
    pass

def format_zotero_collections(reference: dict, zotero_collections: dict) -> list:
    pass

# Functions for Notion Data Properties
def notion_title(reference: list) -> dict:
    return {
        "title": [
            {
                "text": {
                    "content": reference["data"]["title"]
                }
            }
        ]
    }

def notion_collections(zotero_collection_names: list) -> dict:
    return {
        "multi_select": [
            {
                "name": collection
            }
            for collection in zotero_collection_names if zotero_collection_names
        ]
    }

def notion_authors(authors: str) -> dict:
    ...

def notion_source_url(reference: dict) -> dict:
    ...

def notion_tags(reference: dict) -> dict:
    ...

def notion_item_type(reference: dict) -> dict:
    ...

def notion_publisher(reference: dict) -> dict:
    ...

def notion_extra(reference: dict) -> dict:
    ...

def notion_doi(reference: dict) -> dict:
    ...

def notion_abstract(abstract: str) -> dict:
    pass

def notion_status():
    pass

def notion_category():
    pass

def notion_access_date(access_date: str) -> dict:
    pass

def notion_publication_date(publication_date: str) -> dict:
    ...
    
def notion_modified_date(modified_date: str) -> dict:
    pass

def sync_to_notion(reference: dict, zotero_collections: dict) -> None:
    # Convert the authors to a comma-separated string required by Notion's multi_select field, Zotero gives a list of dictionaries instead (example: `'creators': [ { 'creatorType': 'author', 'firstName': 'Qiulin', 'lastName': 'Chen' }, { 'creatorType': 'author', 'firstName': 'Duo', 'lastName': 'Xu' }, { 'creatorType': 'author', 'firstName': 'Yi', 'lastName': 'Zhou' } ]`)
    authors: Optional[str] = format_authors()
    
    # Convert the dynamic zotero data to notion-compatible one ('YYYY-MM-DD' or 'YYYY-MM-DD HH:mm:ss'). Zotero's date can take different forms: `"%Y-%m-%dT%H:%M:%S%z",`, `"%Y-%m-%d"`, `"%Y/%m"`, or `"%Y"`
    access_date: Optional[str] = parse_date()
    publication_date: Optional[str] = parse_date()
    modified_date: Optional[str] = parse_date()
    
    # Process abstract (truncate to 2000 characters if too long)
    abstract: Optional[str] = process_abstract()
    
    # Convert the zotero_collections dict to a list of collection names
    zotero_collection_names: list = format_zotero_collections()
    
    # Prepare data for notion
    notion_data_parent: dict = {"database_id": notion_db_id}
    
    notion_data_properties_title: dict = notion_title(reference=reference)
    notion_data_properties_collections: dict = notion_collections(zotero_collection_names=zotero_collection_names)
    notion_data_properties_authors: dict = notion_authors(authors=authors)
    notion_data_properties_source_url: dict = notion_source_url(reference=reference)
    notion_data_properties_tags: dict = notion_tags(reference=reference)
    notion_data_properties_item_type: dict = notion_item_type(reference=reference)
    notion_data_properties_publisher: dict = notion_publisher(reference=reference)
    notion_data_properties_extra: dict = notion_extra(reference=reference)
    notion_data_properties_doi: dict = notion_doi(reference=reference)
    notion_data_properties_abstract: dict = notion_abstract(abstract=abstract)
    notion_data_properties_status: dict = notion_status()
    notion_data_properties_category: dict = notion_category()
    notion_data_properties_access_date: dict = notion_access_date(access_date=access_date)
    notion_data_properties_publication_date: dict = notion_publication_date(publication_date=publication_date)
    notion_data_properties_modified_date: dict = notion_modified_date(modified_date=modified_date)

    data_for_notion = {
        "parent": notion_data_parent,
        "properties": {
            nt_title: notion_data_properties_title,
            nt_collections: notion_data_properties_collections,
            nt_authors: notion_data_properties_authors,
            nt_source_url: notion_data_properties_source_url,
            nt_tags: notion_data_properties_tags,
            nt_item_type: notion_data_properties_item_type,
            nt_publisher: notion_data_properties_publisher,
            nt_extra: notion_data_properties_extra,
            nt_doi: notion_data_properties_doi,
            nt_abstract: notion_data_properties_abstract,
            nt_status: notion_data_properties_status,
            nt_category: notion_data_properties_category,
            nt_date_accessed: notion_data_properties_access_date,
            nt_publication_date: notion_data_properties_publication_date,
            nt_modified_date: notion_data_properties_modified_date,
        }
    }

# Main function

def update_reference_in_notion(notion_page_id: str, reference: dict, zotero_collection_names: list) -> None:
    pass

def add_reference_to_notion(reference: dict, zotero_collections: dict) -> None:
    
    # Check if the reference already exists in Notion by retrieving its ID (a.k.a., page ID)
    notion_page_id: Optional[str] = find_matching_notion_page_id()
    
    if notion_page_id:
        update_reference_in_notion(notion_page_id=notion_page_id, reference=reference, zotero_collection_names=zotero_collection_names)
        return

# %%
find_matching_notion_page_id(
    title="AI’s Effects on Economic Growth in Aging Society: Induced Innovation and Labor Supplemental Substitution",
    zotero_collection_names=['AI']
)
